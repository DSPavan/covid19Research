# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

#import pytraj as pt

import nglview as nv
import ipywidgets
# Out:
# A Jupyter Widget

# %%
# !jupyter-nbextension enable --py --user widgetsnbextension
# !jupyter-nbextension enable --py --user nglview
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok
# Enabling notebook extension nglview-js-widgets/extension...
#       - Validating: ok

# %%
#!jupyter --paths

# %%
temperature = np.genfromtxt([i for i in open('C:\\Users\\radha\\Desktop\\20nsXVG\\temperature.xvg').read().splitlines() 
    if not i.startswith(('#','@'))])
plt.plot(*temperature.T)
plt.title('temperature')
plt.xlabel('Time (ps)')
plt.ylabel('(K)')

# %%
# density
density= np.genfromtxt([i for i in open('C:\\Users\\radha\\Desktop\\20nsXVG\\density.xvg').read().splitlines() 
    if not i.startswith(('#','@'))])
plt.plot(*density.T)
plt.title('Density')
plt.xlabel('Time (ps)')
plt.ylabel('(kg/m^3)')

# %%
pressure = np.genfromtxt([i for i in open('C:\\Users\\radha\\Desktop\\20nsXVG\\pressure.xvg').read().splitlines() 
    if not i.startswith(('#','@'))])
plt.plot(*pressure.T)
plt.title('pressure')
plt.xlabel('time-ps')
plt.ylabel('(bar)')

# %%
Totalenergy = np.genfromtxt([i for i in open('C:\\Users\\radha\\Desktop\\20nsXVG\\Totalenergy.xvg').read().splitlines() 
    if not i.startswith(('#','@'))])
plt.plot(*Totalenergy.T)
plt.title('Totalenergy')
plt.xlabel('time-ps')
plt.ylabel('(kJ/mol)')

# %%
potentialEnergy = np.genfromtxt([i for i in open('C:\\Users\\radha\\Desktop\\20nsXVG\\potentialEnergy.xvg').read().splitlines() 
    if not i.startswith(('#','@'))])
plt.plot(*potentialEnergy.T)
plt.title('potentialEnergy')
plt.xlabel('time-ps')
plt.ylabel('(kJ/mol)')

# %%
rmsf = np.genfromtxt([i for i in open('C:\\Users\\radha\\Desktop\\20nsXVG\\rmsf.xvg').read().splitlines() 
    if not i.startswith(('#','@'))])
plt.plot(*rmsf.T)
plt.title('rmsf Clapha')
plt.xlabel('time-ps')
plt.ylabel('RMSD (nm)')

# %%
resid, rmsf = np.loadtxt("C:\\Users\\radha\\Desktop\\20nsXVG\\rmsf.xvg", unpack=True)

fig = plt.figure(figsize=(5,2.5))
ax = fig.add_subplot(111)
fig.subplots_adjust(bottom=0.2)

ax.fill_between(resid, rmsf, color="red", linestyle="-", alpha=0.1)
ax.plot(resid, rmsf, color="blue", linestyle="-")

ax.set_xlabel("Frame number - Residue Number")
ax.set_ylabel(r"C$_\alpha$ RMSF (nm)")
ax.set_xlim(resid.min(), resid.max())

fig.savefig("rmsf_ca.png", dpi=300)
fig.savefig("rmsf_ca.svg")
fig.savefig("rmsf_ca.pdf")

# %%
t,data,x,y,z = np.loadtxt("C:\\Users\\radha\\Desktop\\20nsXVG\\gyrate_protein20ns_calpha.xvg", unpack=True)

fig = plt.figure(figsize=(5,2.5))
ax = fig.add_subplot(111)
fig.subplots_adjust(bottom=0.2)

ax.fill_between(t,x, color="magenta", linestyle="-", alpha=0.1)

ax.plot(t,data, color="green", linestyle="-")

ax.set_xlabel("Gyrate - DATA \ntime $t$ (ps)")
ax.set_ylabel(r"protein $R_\mathrm{gyr}$ (nm)")

fig.savefig("rgyr.png", dpi=300)
fig.savefig("rgyr.svg")
fig.savefig("rgyr.pdf")
# Gyrate - DATA

# %%
distance = np.genfromtxt([i for i in open('C:\\Users\\radha\\Desktop\\20nsXVG\\distancePr.xvg').read().splitlines() 
    if not i.startswith(('#','@'))])
    
plt.plot(distance.T[-1])
plt.title('Distance')
plt.xlabel('Time (ps)')
plt.ylabel('Distance (nm)')

# %%
# # Calpha atoms (Group 3). and protein - 1
#RMSD AT C Alpha
rmsd = np.genfromtxt([i for i in open('C:\\Users\\radha\\Desktop\\20nsXVG\\rmsd_pdb.xvg').read().splitlines() 
    if not i.startswith(('#','@'))])
plt.plot(*rmsd.T)
plt.title('RMSD Protein after lsq fit to C-alpha')
plt.xlabel('Time (ns)')
plt.ylabel('RMSD (nm)')

# 0.1 nm = 1 A ( Angstrom)
# Good RMSD

# %%
# rmsf_pdb.xvg , 
rmsf = np.genfromtxt([i for i in open('C:\\Users\\radha\\Desktop\\20nsXVG\\rmsf_pdb.xvg').read().splitlines() 
    if not i.startswith(('#','@'))])
plt.plot(*rmsf.T)
plt.title('rmsf RMS fluctuation')
plt.xlabel('Atom"')
plt.ylabel('nm')

# Most of the data is in 0.15 nm
# GOOD

# %%
#gyrate  Rgyr is a measure for the compactness of a structure
t,data,x,y,z = np.loadtxt("C:\\Users\\radha\\Desktop\\20nsXVG\\gyrate_pdb.xvg", unpack=True)

fig = plt.figure(figsize=(5,2.5))
ax = fig.add_subplot(111)
fig.subplots_adjust(bottom=0.2)

ax.fill_between(t,x, color="magenta", linestyle="-", alpha=0.1)
ax.fill_between(t,y, color="blue", linestyle="-", alpha=0.1)
ax.fill_between(t,z, color="yellow", linestyle="-", alpha=0.1)

ax.plot(t,data, color="green", linestyle="-")

ax.set_xlabel("Gyrate - DATA \ntime $t$ (ps)")
ax.set_ylabel(r"protein $R_\mathrm{gyr}$ (nm)")

fig.savefig("rgyr.png", dpi=300)
fig.savefig("rgyr.svg")
fig.savefig("rgyr.pdf")
# Gyrate - DATA

# Radius of gyration (total and around axes
#xaxis  label "Time (ps) - 1000ps = 1ns"
#yaxis label "Rg (nm) - data

# %%
# dustance on Resude 47 - Active site
distance = np.genfromtxt([i for i in open('C:\\Users\\radha\\Desktop\\20nsXVG\\NC_dist_r47.xvg').read().splitlines() 
    if not i.startswith(('#','@'))])
    
plt.plot(distance.T[-1])
plt.title('Distance')
plt.xlabel('Time (ps)')
plt.ylabel('Distance (nm)')

# %%
# dustance on Resude 138 - Active site
distance = np.genfromtxt([i for i in open('C:\\Users\\radha\\Desktop\\20nsXVG\\NC_dist_r138.xvg').read().splitlines() 
    if not i.startswith(('#','@'))])
    
plt.plot(distance.T[-1])
plt.title('Distance')
plt.xlabel('Time (ps)')
plt.ylabel('Distance (nm)')

# %%
#gyrate  Rgyr is a measure for the compactness of a structure
t,hb,pairs = np.loadtxt("C:\\Users\\radha\\Desktop\\20nsXVG\\july10\\hbnum.xvg", unpack=True)

fig = plt.figure(figsize=(5,5))
fig.suptitle('No of Hydrogen Bonds Vs a time', fontsize=16)
ax = fig.add_subplot(111)
fig.subplots_adjust(bottom=0.2)

#ax.fill_between(t,x, color="magenta", linestyle="-", alpha=0.1)

t = t/1000
ax.plot(t,hb, color="green", linestyle="-")

ax.set_xlabel(" - DATA \ntime $t$ (ps)")
ax.set_ylabel('No of Hydrogen bonds')

fig.savefig("hb.png", dpi=300)

# %%
#hbondnum_Pro-Sol.xvg
#gyrate  Rgyr is a measure for the compactness of a structure
t,hb,pairs = np.loadtxt("C:\\Users\\radha\\Desktop\\20nsXVG\\july2\\hbondnum_Pro-sol.xvg", unpack=True)

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)
fig.subplots_adjust(bottom=0.2)

#ax.fill_between(t,x, color="magenta", linestyle="-", alpha=0.1)


ax.plot(t,hb, color="green", linestyle="-")

ax.set_xlabel(" - DATA \ntime $t$ (ps)")
ax.set_ylabel('No of Hydrogen bonds')

fig.savefig("hb.png", dpi=300)

# %%
# Conclusions
## Gyrate 3.0 nm
## RMSF 0.1 to 0.3 nm
# RMSD  0.1 nm = 1 A
# Distance 0.1 to 0.3nm
#Energy                      Average   Err.Est.       RMSD  Tot-Drift
#-------------------------------------------------------------------------------
#Potential                -3.34042e+06      55000     157334    -356607  (kJ/mol)
#Temperature                 299.861       0.22    3.11634    1.10553  (K)
#Density                     1019.83       0.19    1.81389   0.311293  (kg/m^3)
#Pressure                   -2.87929        1.9    72.3636  -0.715796  (bar)
#Total Energy             -2.46364e+06        130    2433.43    8.83357  (kJ/mol)

#
#The RMSD ranges from 0.0545973 to 0.2705 nm
#Average RMSD is 0.143994

# %%
#gyrate  Rgyr is a measure for the compactness of a structure
t,hb = np.loadtxt("C:\\Users\\radha\\Desktop\\20nsXVG\\july10\\hbdist.xvg", unpack=True)

fig = plt.figure(figsize=(5,5))
fig.suptitle('Hydrogen Bond Distribution Vs a time', fontsize=16)
ax = fig.add_subplot(111)
fig.subplots_adjust(bottom=0.2)

#ax.fill_between(t,x, color="magenta", linestyle="-", alpha=0.1)


ax.plot(hb,t ,color="green", linestyle="-")

ax.set_xlabel(" - DATA \ntime $t$ (ps)")
ax.set_ylabel('Donor - Acceptor Distance (nm)')
# Title = Hydrogen Bond Distribution
fig.savefig("hb.png", dpi=300)

# %%
# # Calpha atoms (Group 3). and protein - 1
#RMSD AT C Alpha
rmsd = np.genfromtxt([i for i in open('C:\\Users\\radha\\Desktop\\20nsXVG\\july10\\rmsd_pdb_backbone.xvg').read().splitlines() 
    if not i.startswith(('#','@'))])
plt.plot(*rmsd.T)
plt.title('RMSD Protein after lsq fit to backbone')
plt.xlabel('Time (ns)')
plt.ylabel('RMSD (nm)')

# 0.1 nm = 1 A ( Angstrom)
# Good RMSD

# %%
#gyrate  Rgyr is a measure for the compactness of a structure
t,hb = np.loadtxt("C:\\Users\\radha\\Desktop\\20nsXVG\\july10\\clust-id.xvg", unpack=True)

fig = plt.figure(figsize=(5,5))
fig.suptitle('Clusters over a time : C Alpha , Protein: Cut-Off 0.15nm', fontsize=16)
ax = fig.add_subplot(111)
fig.subplots_adjust(bottom=0.2)

#ax.fill_between(t,x, color="magenta", linestyle="-", alpha=0.1)


ax.plot(t,hb ,color="green", linestyle="-")

ax.set_xlabel("Number of  Cluster #")
ax.set_ylabel('Time (ns)')
# Title = Hydrogen Bond Distribution
fig.savefig("hb.png", dpi=300)
